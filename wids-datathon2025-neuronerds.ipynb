# %% [markdown]
# <a href="https://www.kaggle.com/code/aleksbaran/wids-datathon2025-neuronerds?scriptVersionId=237420706" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # 🧠 8th Annual WiDS Datathon: Unraveling the Mysteries of the Female Brain
#
# ## Project Summary
#
# This notebook presents an overview of our contribution to the **8th Annual Women in Data Science (WiDS) Datathon**, focused on analyzing brain activity patterns associated with **ADHD (Attention-Deficit/Hyperactivity Disorder)** and exploring **how these patterns differ between males and females**. The central dataset in this challenge comprises **functional MRI (fMRI) connectome matrices**, capturing dynamic brain activity, complemented by rich metadata including socio-demographic factors, emotional assessments, and parenting information.
#
# ---
#
# ## 🔍 Core Challenge
#
# > **“What brain activity patterns are associated with ADHD? Are they different between males and females, and, if so, how?”**
#
# Our objective is two-fold:
# 1. **Predict ADHD diagnosis** using neuroimaging and behavioral data.
# 2. **Model sex-based differences** in brain activity patterns, particularly in individuals diagnosed with ADHD.
#
# ---
#
# ## 📦 Data Overview
#
# The dataset includes:
# - Functional connectome matrices derived from fMRI scans
# - Subject-level metadata: age, sex, emotions, behavioral and parenting scores
# - Labels: ADHD diagnosis and biological sex
#
# This high-dimensional and multimodal dataset presents both challenges and opportunities for building robust predictive models and uncovering underlying neurological patterns.
#
# ---
#
# ## 🛠️ Methodology & Workflow
#
# Our workflow is structured as follows:
#
# 1. **[Exploratory Data Analysis](https://github.com/alexabaran/WIDS_datathon_2025/blob/main/notebooks/01_eda.ipynb)**
#    Visual and statistical exploration of the input features, distributions, and correlations.
#
# 2. **[Preprocessing](https://github.com/alexabaran/WIDS_datathon_2025/blob/main/notebooks/02_preprocessing.ipynb)**
#    Data cleaning, feature engineering, normalization, and dimensionality reduction.
#
# 3. **[Modeling](https://github.com/alexabaran/WIDS_datathon_2025/blob/main/notebooks/03_modelling.ipynb)**
#    Comparison of multiple machine learning models (Logistic Regression, Random Forest, XGBoost, Neural Networks) for both classification tasks.
#
# 4. **[Evaluation](https://github.com/alexabaran/WIDS_datathon_2025/blob/main/notebooks/04_evaluation.ipynb)**
#    Final performance metrics, confusion matrices, and interpretability insights.
#
# ---
#
# ## 📊 Performance
#
# We evaluate models using:
# - Accuracy, Precision, Recall, F1-Score
